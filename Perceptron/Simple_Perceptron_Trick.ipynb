# %% [markdown]
# <a href="https://colab.research.google.com/github/SmartDogy/Deep-Fried-Learning/blob/main/Simple_Perceptron_Trick.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

from sklearn.datasets import make_blobs
from sklearn.linear_model import LogisticRegression

# %%
X, Y = make_blobs(n_samples=150, n_features=2, centers=2, random_state=3)

# %%
from logging import Handler
plt.scatter(X[:, 0], X[:, 1], c=Y, cmap='bwr',s=100, edgecolors='black')

red = mpatches.Patch(color='red', label = '0')
blue = mpatches.Patch(color='blue', label = '1')

plt.legend(handles = [red, blue])

# %%
def perceptron(X, Y):
    X = np.insert(X, 0, 1, axis=1)
    weights = np.ones(X.shape[1])
    lr = 0.1

    for i in range(1000):
        j = np.random.randint(0, X.shape[0])
        y_hat = step(np.dot(X[j], weights))
        weights = weights + (lr * (Y[j] - y_hat)) * X[j]

    return weights

# %%
def step(val):
  if val >= 0:
    return 1

  else:
    return 0

# %%
perceptron(X, Y)
# Out:
# array([ 0.9       , -0.37465113, -0.5095445 ])
